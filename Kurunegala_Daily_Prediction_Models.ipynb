# %% [markdown]
# <a href="https://colab.research.google.com/github/RanxduG/Sri-Lanka-Formaldehyde-Level-Analysis/blob/main/Kurunegala_Daily_Prediction_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Importing Libraries**

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Kurunegala_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Data Engineering Coursework/Full/kurunegala_joined_data.csv')

# %% [markdown]
# #**Preparing Data**

# %%
Kurunegala_data.rename(columns={'HCHO reading': 'HCHO_reading'}, inplace=True)

# %%
features = ['HCHO_reading', 'RH2M', 'WD10M', 'QV2M', 'WS10M', 'TS', 'PS', 'PRECTOTCORR', 'date']
Kurunegala_selected = Kurunegala_data[features]

# %%
Kurunegala_selected['date'] = pd.to_datetime(Kurunegala_selected['date'])
Kurunegala_selected = Kurunegala_selected.set_index('date')
# Out:
# <ipython-input-6-a9460feac730>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Kurunegala_selected['date'] = pd.to_datetime(Kurunegala_selected['date'])

# %%
Kurunegala_selected
# Out:
#             HCHO_reading   RH2M  WD10M   QV2M  WS10M     TS     PS  \
# date
# 2019-01-01      0.000088  87.81  47.31  14.47   4.32  21.86  98.16
# 2019-01-02      0.000137  87.06  44.06  13.98   4.03  21.30  98.14
# 2019-01-03      0.000148  86.38  38.00  13.55   3.91  20.98  98.19
# 2019-01-04      0.000000  86.06  45.06  13.31   3.81  20.59  98.13
# 2019-01-05      0.000249  88.88  42.44  15.44   4.02  22.37  97.99
# ...                  ...    ...    ...    ...    ...    ...    ...
# 2023-12-27      0.000075  92.75  50.25  19.10   5.76  25.13  97.81
# 2023-12-28      0.000102  94.75  65.88  19.41   5.27  24.83  97.78
# 2023-12-29      0.000102  93.12  67.00  18.74   4.62  24.59  97.84
# 2023-12-30      0.000158  93.75  55.94  18.07   4.88  23.92  97.84
# 2023-12-31      0.000102  91.69  54.50  18.01   4.85  24.37  97.83
#
#             PRECTOTCORR
# date
# 2019-01-01         0.09
# 2019-01-02         0.01
# 2019-01-03         0.02
# 2019-01-04         0.00
# 2019-01-05         0.04
# ...                 ...
# 2023-12-27        14.56
# 2023-12-28        14.48
# 2023-12-29         9.29
# 2023-12-30         6.99
# 2023-12-31         8.61
#
# [1826 rows x 8 columns]

# %%
plt.figure(figsize=(24, 12))
Kurunegala_selected['HCHO_reading'].plot(label='Daily Levels')
plt.title("Series of Daily Recordings of HCHO Level")
plt.legend()
plt.show()

# %% [markdown]
# #**Performing ADF test, ACF & PACF**

# %%
from statsmodels.tsa.stattools import adfuller

X = Kurunegala_selected.HCHO_reading.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.127328
# p-value: 0.000012
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
series = Kurunegala_selected.HCHO_reading.values
plot_acf(series, lags=30)
plot_pacf(series, lags=30)
plt.show()

# %% [markdown]
# #**Spliting train and test data**

# %%
split_index = int(len(Kurunegala_selected) * 0.8)

# Splitting the data into training and test sets
train_data = Kurunegala_selected.iloc[:split_index]
test_data = Kurunegala_selected.iloc[split_index:]

print("Length of training set:", len(train_data))
print("Length of test set:", len(test_data))
# Out:
# Length of training set: 1460
# Length of test set: 366

# %% [markdown]
# #**Univariable ARIMA**

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(train_data['HCHO_reading'], order=(3,0,2))
model_fit = model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
from sklearn.metrics import mean_squared_error
forecast = model_fit.forecast(steps=len(test_data['HCHO_reading']))
print(forecast)

mse = mean_squared_error(test_data['HCHO_reading'], forecast)
print("MSE : ", mse)

rsme = np.sqrt(mse)
print("RSME : ", rsme)

plt.plot(test_data['HCHO_reading'], label="Actual")
plt.plot(forecast, label="Forecast", color="red")
plt.legend()
plt.show()
# Out:
# 2022-12-31    0.000135
# 2023-01-01    0.000138
# 2023-01-02    0.000136
# 2023-01-03    0.000137
# 2023-01-04    0.000137
#                 ...
# 2023-12-27    0.000132
# 2023-12-28    0.000132
# 2023-12-29    0.000132
# 2023-12-30    0.000132
# 2023-12-31    0.000132
# Freq: D, Name: predicted_mean, Length: 366, dtype: float64
# MSE :  4.5017032598825535e-09
# RSME :  6.709473347351901e-05

# %% [markdown]
# #**Univariable SARIMAX**

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# # SARIMA modeling (continued from original code)
order = (5, 0, 1)  # Non-seasonal parameters
seasonal_order = (5, 0, 1, 12)  # Seasonal parameters, here assuming a yearly seasonal pattern

# Fit SARIMA model
model = SARIMAX(train_data['HCHO_reading'], order=order, seasonal_order=seasonal_order)
model_fit = model.fit(disp=False)

# Forecast
forecast = model_fit.forecast(steps=len(test_data['HCHO_reading']))
# print(forecast)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Calculate MSE and RMSE
mse = mean_squared_error(test_data['HCHO_reading'], forecast)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)

# Visualize actual vs forecast
plt.figure(figsize=(12,6))
plt.plot(Kurunegala_selected['HCHO_reading'], label="Actual")
plt.plot(forecast, label="Forecast", color="red")
plt.legend()
plt.title('Actual vs Forecast SARIMA')
plt.show()
# Out:
# MSE: 4.598805275237012e-09
# RMSE: 6.781449163148694e-05

# %% [markdown]
# #**Multivariable SARIMAX**

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# SARIMA modeling
order = (5, 0, 1)  # Non-seasonal parameters
seasonal_order = (5, 0, 1, 12)  # Seasonal parameters, assuming a yearly seasonal pattern

# Combine exogenous variables
exog_cols = ['RH2M', 'WD10M', 'QV2M', 'WS10M', 'TS', 'PS', 'PRECTOTCORR']
exog_data = train_data[exog_cols]  # Assuming train_data is your DataFrame containing all variables
exog_data_test = test_data[exog_cols]  # Assuming test_data is your DataFrame containing all variables

# Fit SARIMAX model with exogenous variables
model = SARIMAX(train_data['HCHO_reading'], exog=exog_data, order=order, seasonal_order=seasonal_order)
model_fit = model.fit(disp=False)

# Forecast
forecast = model_fit.forecast(steps=len(test_data['HCHO_reading']), exog=exog_data_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Calculate MSE and RMSE
mse = mean_squared_error(test_data['HCHO_reading'], forecast)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)

# Visualize actual vs forecast
plt.figure(figsize=(12,6))
plt.plot(test_data['HCHO_reading'], label="Actual")
plt.plot(forecast, label="Forecast", color="red")
plt.legend()
plt.title('Actual vs Forecast SARIMA')
plt.show()
# Out:
# MSE: 4.342744415472662e-09
# RMSE: 6.589950239169232e-05

# %% [markdown]
# # **Basian Ridge**

# %%
features = ['RH2M', 'WD10M', 'QV2M', 'WS10M', 'TS', 'PS', 'PRECTOTCORR']
exog_data = train_data[features]

# %%
from sklearn.preprocessing import StandardScaler

def create_time_features(df, target=None):
    """
    Creates time series features from datetime index and includes relative humidity
    """


    y = df[target]
    X = df.drop([target], axis=1)

    print(X)
    print(y)

    return X, y


X_train_df, y_train = create_time_features(train_data, target='HCHO_reading')
X_test_df, y_test = create_time_features(test_data, target='HCHO_reading')

X_train_df

scaler = StandardScaler()
scaler.fit(X_train_df)
X_train = scaler.transform(X_train_df)
X_test = scaler.transform(X_test_df)

X_train_df = pd.DataFrame(X_train, columns=X_train_df.columns)
X_test_df = pd.DataFrame(X_test, columns=X_test_df.columns)

X_train_df['Current Date'] = X_train_df.index
X_test_df['Current Date'] = X_test_df.index
# Out:
#              RH2M   WD10M   QV2M  WS10M     TS     PS  PRECTOTCORR
# date
# 2019-01-01  87.81   47.31  14.47   4.32  21.86  98.16         0.09
# 2019-01-02  87.06   44.06  13.98   4.03  21.30  98.14         0.01
# 2019-01-03  86.38   38.00  13.55   3.91  20.98  98.19         0.02
# 2019-01-04  86.06   45.06  13.31   3.81  20.59  98.13         0.00
# 2019-01-05  88.88   42.44  15.44   4.02  22.37  97.99         0.04
# ...           ...     ...    ...    ...    ...    ...          ...
# 2022-12-26  92.12  145.31  18.01   3.35  23.90  97.55         8.57
# 2022-12-27  87.56  102.31  16.78   2.09  24.17  97.91         1.39
# 2022-12-28  90.94   78.56  16.97   3.33  23.72  98.01         0.76
# 2022-12-29  90.62   69.88  16.11   4.16  22.76  98.13         0.04
# 2022-12-30  89.56   58.81  15.26   3.92  22.08  98.20         0.00
#
# [1460 rows x 7 columns]
# date
# 2019-01-01    0.000088
# 2019-01-02    0.000137
# 2019-01-03    0.000148
# 2019-01-04    0.000000
# 2019-01-05    0.000249
#                 ...
# 2022-12-26    0.000123
# 2022-12-27    0.000204
# 2022-12-28    0.000123
# 2022-12-29    0.000224
# 2022-12-30    0.000124
# Name: HCHO_reading, Length: 1460, dtype: float64
#              RH2M  WD10M   QV2M  WS10M     TS     PS  PRECTOTCORR
# date
# 2022-12-31  90.25  55.31  15.20   3.48  21.86  98.17         0.00
# 2023-01-01  90.31  46.25  15.38   3.77  22.15  98.10         0.01
# 2023-01-02  90.31  56.81  15.08   3.93  21.65  98.04         0.01
# 2023-01-03  88.00  44.19  14.40   3.84  21.41  98.05         0.00
# 2023-01-04  88.94  44.50  14.95   4.00  21.89  97.94         0.22
# ...           ...    ...    ...    ...    ...    ...          ...
# 2023-12-27  92.75  50.25  19.10   5.76  25.13  97.81        14.56
# 2023-12-28  94.75  65.88  19.41   5.27  24.83  97.78        14.48
# 2023-12-29  93.12  67.00  18.74   4.62  24.59  97.84         9.29
# 2023-12-30  93.75  55.94  18.07   4.88  23.92  97.84         6.99
# 2023-12-31  91.69  54.50  18.01   4.85  24.37  97.83         8.61
#
# [366 rows x 7 columns]
# date
# 2022-12-31    0.000123
# 2023-01-01    0.000000
# 2023-01-02    0.000111
# 2023-01-03    0.000002
# 2023-01-04    0.000040
#                 ...
# 2023-12-27    0.000075
# 2023-12-28    0.000102
# 2023-12-29    0.000102
# 2023-12-30    0.000158
# 2023-12-31    0.000102
# Name: HCHO_reading, Length: 366, dtype: float64

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Initialize and fit the Bayesian Ridge model
bayesian_ridge_model = BayesianRidge()
bayesian_ridge_model.fit(X_train_df, train_data['HCHO_reading'])

# Predict on test data
bayesian_ridge_predictions = bayesian_ridge_model.predict(X_test_df)

# Calculate MSE and RMSE
mse = mean_squared_error(test_data['HCHO_reading'], bayesian_ridge_predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)

# Visualize actual vs forecast
plt.figure(figsize=(12,6))
plt.plot(test_data.index, test_data['HCHO_reading'], label="Actual")
plt.plot(test_data.index, bayesian_ridge_predictions, label="Forecast", color="red")
plt.legend()
plt.title('Actual vs Bayesian Ridge SARIMA')
plt.show()
# Out:
# MSE: 4.4533926937766675e-09
# RMSE: 6.673374479059801e-05
